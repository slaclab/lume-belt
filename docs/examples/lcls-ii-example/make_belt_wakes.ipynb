# %%
import numpy as np

# %%
file_path = "wakes/Al5mmgap_flat_0p5um10mm.sdds"
write_file_path = "wakes/rfdata47"
start_line = 7
N_truncate = 5000

data = np.loadtxt(file_path, skiprows=start_line)
print(data)

# %%
data.shape

# %%
belt_data = data[:N_truncate, 1:]

# %%
paddings = np.zeros((N_truncate, 2))

# %%
belt_data = np.hstack((belt_data, paddings))

# %%
np.savetxt(write_file_path, belt_data)

# %%
file_path = "wakes/SS_17.4mmR_100nm_3mm.sdds"
write_file_path = "wakes/rfdata48"
start_line = 7
N_truncate = 5000

data = np.loadtxt(file_path, skiprows=start_line)


belt_data = data[:N_truncate, :2]
paddings = np.zeros((N_truncate, 2))
belt_data = np.hstack((belt_data, paddings))
np.savetxt(write_file_path, belt_data)
